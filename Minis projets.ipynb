# %%
#Mini  projet 1
age = int(input("Bitte geben Sie Ihr Alter ein: "))
gender = str(input("Bitte geben Sie Ihr Geschlecht ein (M für Mann und F für Frau): "))
if gender == 'M' and age >= 18 or gender == 'F' and age >= 18 and age < 36:
     print("Sie sind steuerbar")
else:
     print("sie sind unsteuerbar")
# Out:
# Bitte geben Sie Ihr Alter ein:  35
# Bitte geben Sie Ihr Geschlecht ein (M für Mann und F für Frau):  F
# Sie sind steuerbar

# %%
# Square Root using exponentiation
num = int(input("Enter a number: "))
sr = num ** (1/2)
print("The square root of the given number is ",sr)
# Out:
# Enter a number:  4
# The square root of the given number is  2.0

# %%
# un hommme demande à un roi de prendre une table de damier 10x10, metttre un grain de blé dans la 1e case et 
# dans la case et dans la case suivante le double de la case précédente. Calculer le nbre de grains de blé.
# Solution
b = 1
for i in range(1,101):
    b *= 2 #nombre de grains à la 100èmme case
    s = 1 * ((2**100)-1 / 2-1) # nombre total de grains 
print(s)
# Out:
# 1.2676506002282294e+30

# %%
# Addition des cents premiers nbres nombres entiers naturels
sum = 0
for i in range(0,101):
    sum += i
print(sum)
# pour additionner n entiers naturels positifs on utilise la formule suivante: Sn = (n(n+1)) / 2
# Out:
# 5050

# %%
# Converter Celsius-Fahrenheit / Fahrenheit-celsius
print('"Welcome to the Converter Celsius(°C)-Fahrenheit(°F) / Fahrenheint(°F)-Celsius(°C)"🌡')
while True:
 num = float(input("Enter your Value:  "))
 unit = int(input("Choose the Unit(1 for Celsius() and 2 for Fahrenheit(°F): "))

 if unit == 1:
     res = (num * 1.8) + 32
     print("The given temperature in celsius ist now egal to "+str(res)+" °F.")
 elif unit == 2:
     res2 = (num - 32) / 1.8
     print("The given temperature in celsius ist now egal to "+str(res2)+" °C.")
 answer = input("Would you like to continue ?(yes😀/no😥): ")
 print("\n")
 if answer == 'no':
     break

# %%
# Eine liste erzeugen,in der der Benutzer nach der Ausführung des Codes die Anzahl von Elementen eingeben soll
# Mit der while-Schleife
n = int(input("Wie viele Elemente soll die Liste enthalten : "))
frog =  []
brenda = []
i = 0
while i < n:
    element = input("Bitte Geben Sie das Element "+str(i+1)+" ein: ")
    frog.append(element)
    brenda.append(element)
    i += 1
print(frog, brenda)    
print("\n")

# Mit der for-Schleife
n = int(input("Wie viele Elemente soll die Liste enthalten : "))
frog = []
for i in range(n):
    element = input("Bitte Geben Sie das Element "+str(i+1)+" ein: ")
    frog.append(element)
print(frog)

# %%
n = int(input("How many subjects do you have? : "))
subjects , marks , coefs = [], [], []
#marks = []
#coefs = []
for i in range(n):
    print("Subject "+str(i+1))
    element = input("Enter the name of the subject: ")
    subjects.append(element)
    mark = float(input("Enter the Mark: "))
    marks.append(mark)              
    cof = float(input("Enter the coefficient: "))
    coefs.append(cof)
    print("\n")

for i in range(n):   
    print(f"{subjects[i]:<10} {marks[i]:>10}")
   # print(subjects[i],"  ",marks[i],"  ",coefs[i])   
   # print(marks[i])        
   # print(coefs[i])
# Out:
# How many subjects do you have? :  2
# Subject 1
# Enter the name of the subject:  Maths
# Enter the Mark:  10
# Enter the coefficient:  4
# Subject 2
# Enter the name of the subject:  Biology
# Enter the Mark:  15
# Enter the coefficient:  2
# Maths            10.0
# Biology          15.0

# %%
# Program, um der Mittelwert einem schuler zu berechnen
def average(marks,coefs):
    suma = sumb = 0
    for i in range(n):
        suma += marks[i] * coefs[i]
        sumb += coefs[i]
    moy = suma / sumb
    return moy
#👍 Jetzt richtig

from tabulate import tabulate
n = int(input("Combien de matieres avez-vous? : "))
subjects , marks , coefs = [], [], []
#marks = []
#coefs = []
for i in range(n):
    print("Matière "+str(i+1))
    element = input("Veuillez entrer le nom de la matière: ")
    subjects.append(element)
    mark = float(input("Veuillez entrer la note obtenue: "))
    marks.append(mark)              
    cof = float(input("Veullez entrer le coefficient de la matière: "))
    coefs.append(cof)
    print("\n")
"""    
for i in range(n):   
    print(subjects[i])  
    print(marks[i])        
    print(coefs[i])    
    print("\n")
"""
table = list(zip(subjects, marks, coefs))
print(tabulate(table, headers = ["MATIERES", "NOTES", "COEFFICIENTS"], tablefmt = "grid"))

av = average(marks,coefs)
print(f"Moyenne: {av:.2f}")
# Out:
# Combien de matieres avez-vous? :  4
# Matière 1
# Veuillez entrer le nom de la matière:  Mathematiques
# Veuillez entrer la note obtenue:  09.5
# Veullez entrer le coefficient de la matière:  4
# Matière 2
# Veuillez entrer le nom de la matière:  Physique
# Veuillez entrer la note obtenue:  12.5
# Veullez entrer le coefficient de la matière:  3
# Matière 3
# Veuillez entrer le nom de la matière:  Chimie
# Veuillez entrer la note obtenue:  17
# Veullez entrer le coefficient de la matière:  3
# Matière 4
# Veuillez entrer le nom de la matière:  Informatique
# Veuillez entrer la note obtenue:  18
# Veullez entrer le coefficient de la matière:  2
# +---------------+---------+----------------+
# | MATIERES      | NOTES   | COEFFICIENTS   |
# +===============+=========+================+
# | Mathematiques | 9.5     | 4.0            |
# +---------------+---------+----------------+
# | Physique      | 12.5    | 3.0            |
# +---------------+---------+----------------+
# ...

# %%
#Mini Calculatrice basique
def calculat(a,b):
    if choix == 1:
        res = a + b
        return f"Le resultat de votre addition est {res} ."
    elif choix == 2:
        if a < b:
            return "Le premier nombre doit être plus grand"
        else:
            res = a - b
            return f"Le resultat de votre soustraction est {res} ."
    elif choix == 3:
        res = a * b
        return f"Le resultat de votre multiplicaition est {res} ."
    elif choix == 4:
        if b == 0:
            return "Division par 0 impossible. Veuillez entrer un nombre superieur à 0."
        else:
            res = a / b
            return f"Le resultat de votre division est {res} ."    

print("'Bienvenue dans la calculatrice 🤗'")
while True:
    print("Selectionner l'operation que vous voulez effectuer:")
    print("1- Additon")
    print("2- Soustraction")
    print("3- Multiplication")
    print("4- Division")
    choix = int(input("Votre Choix: "))
    print("\n")
    num1 = float(input("Entrer votre premier nombre: "))
    num2 = float(input("Entrer votre deuxieme nombre: "))
    
    
    result = calculat(num1,num2)
    print(result)
    
    rep = input("Souhaitez-vous continuer?(oui/non): ")
    print("\n")
    if rep == 'non': 
        print("Dommage😢. A la prochaine🖐")
        break

# %%
print(eval(input("Enter Expression: ")))
# Out:
# Enter Expression:  98.4 + 12.5
# 110.9

# %%
#Permutations possibles d'un mot
from itertools import permutations
s = input()
b = list(permutations(s))
print(len(b))
for i in b:
    print(" ".join(i))
# Out:
#  Brunel
# 720
# B r u n e l
# B r u n l e
# B r u e n l
# B r u e l n
# B r u l n e
# B r u l e n
# B r n u e l
# B r n u l e
# B r n e u l
# B r n e l u
# B r n l u e
# B r n l e u
# B r e u n l
# B r e u l n
# B r e n u l
# B r e n l u
# B r e l u n
# B r e l n u
# B r l u n e
# B r l u e n
# B r l n u e
# B r l n e u
# B r l e u n
# B r l e n u
# B u r n e l
# B u r n l e
# B u r e n l
# B u r e l n
# B u r l n e
# B u r l e n
# B u n r e l
# B u n r l e
# B u n e r l
# B u n e l r
# B u n l r e
# B u n l e r
# B u e r n l
# B u e r l n
# B u e n r l
# B u e n l r
# B u e l r n
# B u e l n r
# B u l r n e
# B u l r e n
# B u l n r e
# B u l n e r
# B u l e r n
# B u l e n r
# B n r u e l
# B n r u l e
# B n r e u l
# B n r e l u
# B n r l u e
# B n r l e u
# B n u r e l
# B n u r l e
# B n u e r l
# B n u e l r
# B n u l r e
# B n u l e r
# B n e r u l
# B n e r l u
# B n e u r l
# B n e u l r
# B n e l r u
# B n e l u r
# B n l r u e
# B n l r e u
# B n l u r e
# B n l u e r
# ...

# %%
# conversion seconde-heure
T = int(input("Entrer le temps en secondes: "))
h = T // 3600
r = T % 3600
m = r //60
s = r % 60
print(f"Votre temps correspond à : {h}h : {m}m : {s}s")
# Out:
# Entrer le temps en secondes:  60001
# Votre temps correspond à : 16h : 40m : 1s

# %%
# Table de multiplication
import time
print("Bienvenue sur votre Table de mutiplication")
n = float(input("Veuillez entrer le nombre que vous souhaitez connaître sa table de multiplication: "))
j = int(input("Jusqu'où doit aller la table de multiplication: "))
for i in range(1,j+1):
    print(f"{n} * {i} = {n*i}")
    time.sleep(0.5)
# Out:
# Bienvenue sur votre Table de mutiplication
# 21.0 * 1 = 21.0
# 21.0 * 2 = 42.0
# 21.0 * 3 = 63.0
# 21.0 * 4 = 84.0
# 21.0 * 5 = 105.0
# 21.0 * 6 = 126.0
# 21.0 * 7 = 147.0
# 21.0 * 8 = 168.0
# 21.0 * 9 = 189.0
# 21.0 * 10 = 210.0
# 21.0 * 11 = 231.0
# 21.0 * 12 = 252.0
# 21.0 * 13 = 273.0
# 21.0 * 14 = 294.0
# 21.0 * 15 = 315.0
# 21.0 * 16 = 336.0
# 21.0 * 17 = 357.0
# 21.0 * 18 = 378.0
# 21.0 * 19 = 399.0
# 21.0 * 20 = 420.0
# 21.0 * 21 = 441.0
# 21.0 * 22 = 462.0
# 21.0 * 23 = 483.0
# 21.0 * 24 = 504.0
# 21.0 * 25 = 525.0
# 21.0 * 26 = 546.0
# 21.0 * 27 = 567.0
# 21.0 * 28 = 588.0
# 21.0 * 29 = 609.0
# 21.0 * 30 = 630.0
# 21.0 * 31 = 651.0
# 21.0 * 32 = 672.0
# 21.0 * 33 = 693.0
# 21.0 * 34 = 714.0
# 21.0 * 35 = 735.0
# 21.0 * 36 = 756.0
# 21.0 * 37 = 777.0
# 21.0 * 38 = 798.0
# 21.0 * 39 = 819.0
# 21.0 * 40 = 840.0
# 21.0 * 41 = 861.0
# 21.0 * 42 = 882.0
# 21.0 * 43 = 903.0
# 21.0 * 44 = 924.0
# 21.0 * 45 = 945.0
# 21.0 * 46 = 966.0
# 21.0 * 47 = 987.0
# 21.0 * 48 = 1008.0
# ...

# %%
while True:
    s = input("Enter a number: ")
    if s.isnumeric():
        s = int(s)
        break
    else:
        print("It is not a number. Try again")
# Out:
# Enter a number:  +237653934226
# It is not a number. Try again
# Enter a number:  237 653934226
# It is not a number. Try again
# Enter a number:  237653934226

# %%
s = "Warrior"
dir(s)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
help(tabulate)
# Out:
# Help on function tabulate in module tabulate:
#
# tabulate(tabular_data, headers=(), tablefmt='simple', floatfmt='g', intfmt='', numalign='default', stralign='default', missingval='', showindex='default', disable_numparse=False, colalign=None, maxcolwidths=None, rowalign=None, maxheadercolwidths=None)
#     Format a fixed width table for pretty printing.
#
#     >>> print(tabulate([[1, 2.34], [-56, "8.999"], ["2", "10001"]]))
#     ---  ---------
#       1      2.34
#     -56      8.999
#       2  10001
#     ---  ---------
#
#     The first required argument (`tabular_data`) can be a
#     list-of-lists (or another iterable of iterables), a list of named
#     tuples, a dictionary of iterables, an iterable of dictionaries,
#     an iterable of dataclasses (Python 3.7+), a two-dimensional NumPy array,
#     NumPy record array, or a Pandas' dataframe.
#
#
#     Table headers
#     -------------
#
#     To print nice column headers, supply the second argument (`headers`):
#
# ...

# %%
from prettytable import PrettyTable
data = []
with open(r"C:\Users\amour\Desktop\Python\Kursmaterialen\Kursmaterialien\data\names.csv") as file:
    for line in file:
        line = line.strip().split(",")
        if line[5] == "Count":
            continue
            
        counts = int(line[5])
            
        if counts > 100 :
            data.append(line)
        
    table = PrettyTable(["ID", "NAMES", "YEARS","GENDERS","STATES","COUNTS"])
    for element in data:
        table.add_row(element)   
    print(table)
    #for element in sorted(data, key = lambda x:x[5]):
        #print(tabulate(element, headers = ))
    #print(tabulate(data, headers = ["ID", "NAMES", "YEARS","GENDERS","STATES","COUNTS"], tablefmt = "grid"))

# %%
import datetime as dt
day_1 = dt.datetime.now()
print(day_1)
day_2 = input("Enter your Date of Birth (dd/mm/yyyy): ")
day_2 = dt.datetime.strptime(day_2, "%d/%m/%Y")
diff = day_1 - day_2
print(f"You have lived for {diff.days} days")
# Out:
# 2024-12-26 12:03:45.875265
# Enter your Date of Birth (dd/mm/yyyy):  12/03/2007
# You have lived for 6499 days

# %%
# Multiplication table with generator
def multi_table(num,ran):
    for i in range(1, ran+1):
        yield str(num)+" x "+str(i)+" = "+ str(num*i)

for element in multi_table(14,10000):
    print(element)
# Out:
# 14 x 1 = 14
# 14 x 2 = 28
# 14 x 3 = 42
# 14 x 4 = 56
# 14 x 5 = 70
# 14 x 6 = 84
# 14 x 7 = 98
# 14 x 8 = 112
# 14 x 9 = 126
# 14 x 10 = 140
# 14 x 11 = 154
# 14 x 12 = 168
# 14 x 13 = 182
# 14 x 14 = 196
# 14 x 15 = 210
# 14 x 16 = 224
# 14 x 17 = 238
# 14 x 18 = 252
# 14 x 19 = 266
# 14 x 20 = 280
# 14 x 21 = 294
# 14 x 22 = 308
# 14 x 23 = 322
# 14 x 24 = 336
# 14 x 25 = 350
# 14 x 26 = 364
# 14 x 27 = 378
# 14 x 28 = 392
# 14 x 29 = 406
# 14 x 30 = 420
# 14 x 31 = 434
# 14 x 32 = 448
# 14 x 33 = 462
# 14 x 34 = 476
# 14 x 35 = 490
# 14 x 36 = 504
# 14 x 37 = 518
# 14 x 38 = 532
# 14 x 39 = 546
# 14 x 40 = 560
# 14 x 41 = 574
# 14 x 42 = 588
# 14 x 43 = 602
# 14 x 44 = 616
# 14 x 45 = 630
# 14 x 46 = 644
# 14 x 47 = 658
# 14 x 48 = 672
# 14 x 49 = 686
# 14 x 50 = 700
# 14 x 51 = 714
# 14 x 52 = 728
# 14 x 53 = 742
# 14 x 54 = 756
# 14 x 55 = 770
# 14 x 56 = 784
# 14 x 57 = 798
# 14 x 58 = 812
# 14 x 59 = 826
# 14 x 60 = 840
# 14 x 61 = 854
# 14 x 62 = 868
# 14 x 63 = 882
# ...
