# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
img = cv2.imread("4112d43fef464f46a1d68b0de05d8369.jpg")
bru = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(bru)
plt.show()

# %%
print(bru.shape)
bru_1 = np.zeros(bru.shape, dtype="uint8") + 50
new = cv2.add(bru, bru_1)
#new = cv2.cvtColor(new, cv2.COLOR_BGR2RGB)
plt.imshow(new)
plt.show()
# Out:
# (808, 1080, 3)
